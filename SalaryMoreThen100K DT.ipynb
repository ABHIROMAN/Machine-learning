# %% [markdown]
# ## ABHISHEK KUMAR
# ## 20BAI10384
#
# ##                   DECISION TREE

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('salary.csv')

# %%
df
# Out:
#     S.No     company                  job     degree  salary_more_then_100k  \
# 0      1      google      sales executive  bachelors                      0
# 1      2      google      sales executive    masters                      0
# 2      3      google     business manager  bachelors                      1
# 3      4      google     business manager    masters                      1
# 4      5      google  computer programmer  bachelors                      0
# 5      6      google  computer programmer    masters                      1
# 6      7  abc pharma      sales executive    masters                      0
# 7      8  abc pharma  computer programmer  bachelors                      0
# 8      9  abc pharma     business manager  bachelors                      0
# 9     10  abc pharma     business manager    masters                      1
# 10    11    facebook      sales executive  bachelors                      1
# 11    12    facebook      sales executive    masters                      1
# 12    13    facebook     business manager  bachelors                      1
# 13    14    facebook     business manager    masters                      1
# 14    15    facebook  computer programmer  bachelors                      1
# 15    16    facebook  computer programmer    masters                      1
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN

# %%
inputs = df.drop(['salary_more_then_100k','Unnamed: 5'], axis= 'columns')
target = df['salary_more_then_100k']

# %%
inputs
# Out:
#     S.No     company                  job     degree
# 0      1      google      sales executive  bachelors
# 1      2      google      sales executive    masters
# 2      3      google     business manager  bachelors
# 3      4      google     business manager    masters
# 4      5      google  computer programmer  bachelors
# 5      6      google  computer programmer    masters
# 6      7  abc pharma      sales executive    masters
# 7      8  abc pharma  computer programmer  bachelors
# 8      9  abc pharma     business manager  bachelors
# 9     10  abc pharma     business manager    masters
# 10    11    facebook      sales executive  bachelors
# 11    12    facebook      sales executive    masters
# 12    13    facebook     business manager  bachelors
# 13    14    facebook     business manager    masters
# 14    15    facebook  computer programmer  bachelors
# 15    16    facebook  computer programmer    masters

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['jobs_n'] = le_company.fit_transform(inputs['job'])
inputs['degree_n'] = le_company.fit_transform(inputs['degree'])
inputs.head()
# Out:
#    S.No company                  job     degree  company_n  jobs_n  degree_n
# 0     1  google      sales executive  bachelors          2       2         0
# 1     2  google      sales executive    masters          2       2         1
# 2     3  google     business manager  bachelors          2       0         0
# 3     4  google     business manager    masters          2       0         1
# 4     5  google  computer programmer  bachelors          2       1         0

# %%
inputs_n = inputs.drop(['company','job','degree','S.No'],axis = 'columns')

# %%
inputs_n
# Out:
#     company_n  jobs_n  degree_n
# 0           2       2         0
# 1           2       2         1
# 2           2       0         0
# 3           2       0         1
# 4           2       1         0
# 5           2       1         1
# 6           0       2         1
# 7           0       1         0
# 8           0       0         0
# 9           0       0         1
# 10          1       2         0
# 11          1       2         1
# 12          1       0         0
# 13          1       0         1
# 14          1       1         0
# 15          1       1         1

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 1.0

# %%
model.predict([[2,2,0]])
# Out:
# /home/prince/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict([[2,2,1]])
# Out:
# /home/prince/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
